# %%
# !pip install tensorflow #installing tensoflow package

# %%
import tensorflow as tf #importing tensorflow packages

# %%
print(tf.__version__) #checking if tensorflow installed correctly
# Out:
# 1.14.0
